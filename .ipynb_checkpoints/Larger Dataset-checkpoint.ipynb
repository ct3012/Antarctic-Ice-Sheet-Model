# %%
import xarray as xr
import gcsfs
gcs = gcsfs.GCSFileSystem(token=None, access='read_only')
ds = xr.open_zarr(gcs.get_mapper('gs://ldeo-glaciology/paleo_ensemble/snapshots1ka.zarr'))

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 125, y: 381, x: 381, par_esia: 4, par_ppq: 4,
#                  par_prec: 4, par_visc: 4)
# Coordinates:
#   * par_esia    (par_esia) float64 1.0 2.0 4.0 7.0
#   * par_ppq     (par_ppq) float64 0.25 0.5 0.75 1.0
#   * par_prec    (par_prec) float64 0.02 0.05 0.07 0.1
#   * par_visc    (par_visc) float64 1e+20 5e+20 2.5e+21 1e+22
#   * time        (time) float64 -1.24e+05 -1.23e+05 -1.22e+05 ... -1e+03 0.0
#   * x           (x) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
#   * y           (y) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
# Data variables:
#     bmelt       (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(25, 381, 381, 1, 4, 4, 4), meta=np.ndarray>
#     dbdt        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(25, 381, 381, 1, 4, 4, 4), meta=np.ndarray>
# ...

# %%
import xarray as xr
import gcsfs
gcs = gcsfs.GCSFileSystem(token=None, access='read_only')
ds = xr.open_zarr(gcs.get_mapper('gs://ldeo-glaciology/paleo_ensemble/snapshots1ka.zarr'))

# %%
ds.usurf.isel(par_esia=3,par_ppq = 2, par_prec= 1,par_visc = 2).plot(size = 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 ds.usurf.isel(par_esia=3,par_ppq = 2, par_prec= 1,par_visc = 2).plot(size = 10)
#
# File ~\anaconda3\lib\site-packages\xarray\plot\plot.py:868, in _PlotMethods.__call__(self, **kwargs)
#     867 def __call__(self, **kwargs):
# --> 868     return plot(self._da, **kwargs)
#
# File ~\anaconda3\lib\site-packages\xarray\plot\plot.py:297, in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     246 def plot(
#     247     darray,
#     248     row=None,
#    (...)
#     255     **kwargs,
#     256 ):
#     257     """
#     258     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     259
#    (...)
#     295     xarray.DataArray.squeeze
#     296     """
# --> 297     darray = darray.squeeze().compute()
# ...
